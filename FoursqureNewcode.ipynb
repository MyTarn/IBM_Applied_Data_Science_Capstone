# %%
import folium
from IPython.core.display import display, HTML

def folium_deepnote_show(m):
    data = m.get_root().render()
    data_fixed_height = data.replace('width: 100%;height: 100%', 'width: 100%').replace('height: 100.0%;', 'height: 609px;', 1)
    display(HTML(data_fixed_height))

# %%
m3 = folium.Map(location=[45.372, -121.6972], zoom_start=12, tiles="Stamen Terrain")

tooltip = "Click me!"

folium.Marker(
    [45.3288, -121.6625], popup="<i>Mt. Hood Meadows</i>", tooltip=tooltip
).add_to(m3)
folium.Marker(
    [45.3311, -121.7113], popup="<b>Timberline Lodge</b>", tooltip=tooltip
).add_to(m3)

folium_deepnote_show(m3)
# Out:
# <!DOCTYPE html>
# <head>
#     <meta http-equiv="content-type" content="text/html; charset=UTF-8" />
#
#         <script>
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         </script>
#
#     <style>html, body {width: 100%;margin: 0;padding: 0;}</style>
#     <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>
#     <script src="https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js"></script>
#     <script src="https://code.jquery.com/jquery-1.12.4.min.js"></script>
#     <script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js"></script>
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js"></script>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css"/>
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css"/>
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css"/>
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css"/>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css"/>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css"/>
#
#             <meta name="viewport" content="width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />
#             <style>
#                 #map_6260e523fea24e668b1e030f327cbe93 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 609px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             </style>
#
# </head>
# <body>
#
#             <div class="folium-map" id="map_6260e523fea24e668b1e030f327cbe93" ></div>
#
# </body>
# <script>
#
#             var map_6260e523fea24e668b1e030f327cbe93 = L.map(
#                 "map_6260e523fea24e668b1e030f327cbe93",
#                 {
#                     center: [45.372, -121.6972],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dcec8aa65ba6441291f1899dbd1ed942 = L.tileLayer(
#                 "https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg",
#                 {"attribution": "Map tiles by \u003ca href=\"http://stamen.com\"\u003eStamen Design\u003c/a\u003e, under \u003ca href=\"http://creativecommons.org/licenses/by/3.0\"\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\"http://openstreetmap.org\"\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\"http://creativecommons.org/licenses/by-sa/3.0\"\u003eCC BY SA\u003c/a\u003e.", "detectRetina": false, "maxNativeZoom": 18, "maxZoom": 18, "minZoom": 0, "noWrap": false, "opacity": 1, "subdomains": "abc", "tms": false}
#             ).addTo(map_6260e523fea24e668b1e030f327cbe93);
#
#
#             var marker_ac85d9756218461c894c32ea8377a3b2 = L.marker(
#                 [45.3288, -121.6625],
#                 {}
#             ).addTo(map_6260e523fea24e668b1e030f327cbe93);
#
#
#         var popup_75d091c002514ba1a2d571ad972777a3 = L.popup({"maxWidth": "100%"});
#
#
#             var html_9c49fdfc87de4e17ad2be18dde36511a = $(`<div id="html_9c49fdfc87de4e17ad2be18dde36511a" style="width: 100.0%; height: 100.0%;"><i>Mt. Hood Meadows</i></div>`)[0];
#             popup_75d091c002514ba1a2d571ad972777a3.setContent(html_9c49fdfc87de4e17ad2be18dde36511a);
#
#
#         marker_ac85d9756218461c894c32ea8377a3b2.bindPopup(popup_75d091c002514ba1a2d571ad972777a3)
#         ;
#
#
#
#
#             marker_ac85d9756218461c894c32ea8377a3b2.bindTooltip(
#                 `<div>
#                      Click me!
#                  </div>`,
#                 {"sticky": true}
#             );
#
#
#             var marker_3e0e48df6b3a439eaab026819d918cd2 = L.marker(
#                 [45.3311, -121.7113],
#                 {}
#             ).addTo(map_6260e523fea24e668b1e030f327cbe93);
#
#
#         var popup_a57947caf5904615a5fba58ef654404f = L.popup({"maxWidth": "100%"});
#
#
#             var html_1375288b033a42cabeb0a8700e43d541 = $(`<div id="html_1375288b033a42cabeb0a8700e43d541" style="width: 100.0%; height: 100.0%;"><b>Timberline Lodge</b></div>`)[0];
#             popup_a57947caf5904615a5fba58ef654404f.setContent(html_1375288b033a42cabeb0a8700e43d541);
#
#
#         marker_3e0e48df6b3a439eaab026819d918cd2.bindPopup(popup_a57947caf5904615a5fba58ef654404f)
#         ;
#
#
#
#
#             marker_3e0e48df6b3a439eaab026819d918cd2.bindTooltip(
#                 `<div>
#                      Click me!
#                  </div>`,
#                 {"sticky": true}
#             );
#
# </script>

# %%
m4 = folium.Map(location=[45.372, -121.6972], zoom_start=12, tiles="Stamen Terrain")

folium.Marker(
    location=[45.3288, -121.6625],
    popup="Mt. Hood Meadows",
    icon=folium.Icon(icon="cloud"),
).add_to(m4)

folium.Marker(
    location=[45.3311, -121.7113],
    popup="Timberline Lodge",
    icon=folium.Icon(color="green"),
).add_to(m4)

folium.Marker(
    location=[45.3300, -121.6823],
    popup="Some Other Location",
    icon=folium.Icon(color="red", icon="info-sign"),
).add_to(m4)


folium_deepnote_show(m4)
# Out:
# <!DOCTYPE html>
# <head>
#     <meta http-equiv="content-type" content="text/html; charset=UTF-8" />
#
#         <script>
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         </script>
#
#     <style>html, body {width: 100%;margin: 0;padding: 0;}</style>
#     <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>
#     <script src="https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js"></script>
#     <script src="https://code.jquery.com/jquery-1.12.4.min.js"></script>
#     <script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js"></script>
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js"></script>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css"/>
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css"/>
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css"/>
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css"/>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css"/>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css"/>
#
#             <meta name="viewport" content="width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />
#             <style>
#                 #map_32237eec6d794dfc95fd56385356a285 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 609px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             </style>
#
# </head>
# <body>
#
#             <div class="folium-map" id="map_32237eec6d794dfc95fd56385356a285" ></div>
#
# </body>
# <script>
#
#             var map_32237eec6d794dfc95fd56385356a285 = L.map(
#                 "map_32237eec6d794dfc95fd56385356a285",
#                 {
#                     center: [45.372, -121.6972],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d594064966f943bebe5e5d213f17a859 = L.tileLayer(
#                 "https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg",
#                 {"attribution": "Map tiles by \u003ca href=\"http://stamen.com\"\u003eStamen Design\u003c/a\u003e, under \u003ca href=\"http://creativecommons.org/licenses/by/3.0\"\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\"http://openstreetmap.org\"\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\"http://creativecommons.org/licenses/by-sa/3.0\"\u003eCC BY SA\u003c/a\u003e.", "detectRetina": false, "maxNativeZoom": 18, "maxZoom": 18, "minZoom": 0, "noWrap": false, "opacity": 1, "subdomains": "abc", "tms": false}
#             ).addTo(map_32237eec6d794dfc95fd56385356a285);
#
#
#             var marker_1ccfe5b1a8044d8d9770b6387f515ff3 = L.marker(
#                 [45.3288, -121.6625],
#                 {}
#             ).addTo(map_32237eec6d794dfc95fd56385356a285);
#
#
#             var icon_1d1dffb432764d5793b0246d16e393fc = L.AwesomeMarkers.icon(
#                 {"extraClasses": "fa-rotate-0", "icon": "cloud", "iconColor": "white", "markerColor": "blue", "prefix": "glyphicon"}
#             );
#             marker_1ccfe5b1a8044d8d9770b6387f515ff3.setIcon(icon_1d1dffb432764d5793b0246d16e393fc);
#
#
#         var popup_393654aefe6348a986fe10249e987739 = L.popup({"maxWidth": "100%"});
#
#
#             var html_73b43922e2174497ae412981f57a0ad5 = $(`<div id="html_73b43922e2174497ae412981f57a0ad5" style="width: 100.0%; height: 100.0%;">Mt. Hood Meadows</div>`)[0];
#             popup_393654aefe6348a986fe10249e987739.setContent(html_73b43922e2174497ae412981f57a0ad5);
#
#
#         marker_1ccfe5b1a8044d8d9770b6387f515ff3.bindPopup(popup_393654aefe6348a986fe10249e987739)
#         ;
#
#
#
#
#             var marker_cd4fc3a026974063a63628e9507bff54 = L.marker(
#                 [45.3311, -121.7113],
#                 {}
#             ).addTo(map_32237eec6d794dfc95fd56385356a285);
#
#
#             var icon_6b1b95736e8547038396ec893b696d58 = L.AwesomeMarkers.icon(
#                 {"extraClasses": "fa-rotate-0", "icon": "info-sign", "iconColor": "white", "markerColor": "green", "prefix": "glyphicon"}
#             );
#             marker_cd4fc3a026974063a63628e9507bff54.setIcon(icon_6b1b95736e8547038396ec893b696d58);
#
#
#         var popup_a9ade647ab9a486abd2b28e6db6e1d53 = L.popup({"maxWidth": "100%"});
#
#
#             var html_d93e2706d8ad48aa977b0d7ee2e96ee6 = $(`<div id="html_d93e2706d8ad48aa977b0d7ee2e96ee6" style="width: 100.0%; height: 100.0%;">Timberline Lodge</div>`)[0];
#             popup_a9ade647ab9a486abd2b28e6db6e1d53.setContent(html_d93e2706d8ad48aa977b0d7ee2e96ee6);
#
#
#         marker_cd4fc3a026974063a63628e9507bff54.bindPopup(popup_a9ade647ab9a486abd2b28e6db6e1d53)
#         ;
#
#
#
#
#             var marker_6a02210206524297bb7c36847c63bccb = L.marker(
#                 [45.33, -121.6823],
#                 {}
#             ).addTo(map_32237eec6d794dfc95fd56385356a285);
#
#
#             var icon_dd230ec6622d4778b7680e89ef3416b7 = L.AwesomeMarkers.icon(
#                 {"extraClasses": "fa-rotate-0", "icon": "info-sign", "iconColor": "white", "markerColor": "red", "prefix": "glyphicon"}
#             );
#             marker_6a02210206524297bb7c36847c63bccb.setIcon(icon_dd230ec6622d4778b7680e89ef3416b7);
#
#
#         var popup_ebcef336320c490cbe7dd24cd48a2548 = L.popup({"maxWidth": "100%"});
#
#
#             var html_a850c387855f47daa6fddbc2f05c996e = $(`<div id="html_a850c387855f47daa6fddbc2f05c996e" style="width: 100.0%; height: 100.0%;">Some Other Location</div>`)[0];
#             popup_ebcef336320c490cbe7dd24cd48a2548.setContent(html_a850c387855f47daa6fddbc2f05c996e);
#
#
#         marker_6a02210206524297bb7c36847c63bccb.bindPopup(popup_ebcef336320c490cbe7dd24cd48a2548)
#         ;
#
#
#
# </script>

# %%
m = folium.Map(location=[40.714742, -74.015169])
folium_deepnote_show(m)
# Out:
# <!DOCTYPE html>
# <head>
#     <meta http-equiv="content-type" content="text/html; charset=UTF-8" />
#
#         <script>
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         </script>
#
#     <style>html, body {width: 100%;margin: 0;padding: 0;}</style>
#     <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>
#     <script src="https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js"></script>
#     <script src="https://code.jquery.com/jquery-1.12.4.min.js"></script>
#     <script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js"></script>
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js"></script>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css"/>
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css"/>
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css"/>
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css"/>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css"/>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css"/>
#
#             <meta name="viewport" content="width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />
#             <style>
#                 #map_2ce067bbb50c4eeeae0f33bd98500c1c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 609px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             </style>
#
# </head>
# <body>
#
#             <div class="folium-map" id="map_2ce067bbb50c4eeeae0f33bd98500c1c" ></div>
#
# </body>
# <script>
#
#             var map_2ce067bbb50c4eeeae0f33bd98500c1c = L.map(
#                 "map_2ce067bbb50c4eeeae0f33bd98500c1c",
#                 {
#                     center: [40.714742, -74.015169],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0d0f0838c1464d23a8216be2383bac96 = L.tileLayer(
#                 "https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png",
#                 {"attribution": "Data by \u0026copy; \u003ca href=\"http://openstreetmap.org\"\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\"http://www.openstreetmap.org/copyright\"\u003eODbL\u003c/a\u003e.", "detectRetina": false, "maxNativeZoom": 18, "maxZoom": 18, "minZoom": 0, "noWrap": false, "opacity": 1, "subdomains": "abc", "tms": false}
#             ).addTo(map_2ce067bbb50c4eeeae0f33bd98500c1c);
#
# </script>
